# %% [markdown]
# ## Análisis de contagios identificados por COVID-19 en Colombia al 27/03/202
#
# Fuente: Gobierno Nacional (datos disponibles en este [enlace](https://coronaviruscolombia.gov.co/Covid19/index.html)).
# Por favor tener presente:
# > Las cifras de contagios en los reportes oficiales **NO refleja la totalidad de contagios** en la población colombiana sino a una fracción menor, correspondiente a los **casos diagnosticados como positivos** en las pruebas de detección realizadas hasta la fecha.

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
confirmed_cases = pd.read_csv("casos_03_27.csv")
confirmed_cases
# Out:
#      ID de caso Fecha de diagnóstico Ciudad de ubicación Departamento  \
# 0             1           06/03/2020              Bogotá       Bogotá
# 1             2           09/03/2020                Buga        Valle
# 2             3           09/03/2020            Medellín    Antioquia
# 3             4           11/03/2020            Medellín    Antioquia
# 4             5           11/03/2020            Medellín    Antioquia
# ..          ...                  ...                 ...          ...
# 534         535            27/3/2020             Soledad    Atlántico
# 535         536            27/3/2020             Armenia      Quindío
# 536         537            27/3/2020             Armenia      Quindío
# 537         538            27/3/2020         Santa Marta  Santa Marta
# 538         539            27/3/2020           Manizales       Caldas
#
#        Atención     Edad Sexo        Tipo* País de procedencia
# 0    Recuperado  10 a 19    F    Importado              Italia
# 1    Recuperado  30 a 39    M    Importado              España
# 2    Recuperado  50 a 59    F    Importado              España
# 3       En casa  50 a 59    M  Relacionado            Colombia
# 4    Recuperado  20 a 29    M  Relacionado            Colombia
# ..          ...      ...  ...          ...                 ...
# 534     En casa  20 a 29    F   En estudio            Colombia
# 535     En casa  40 a 49    F  Relacionado            Colombia
# 536     En casa  30 a 39    F  Relacionado            Colombia
# 537     En casa  60 a 69    F  Relacionado            Colombia
# 538     En casa  80 a 89    M  Relacionado            Colombia
#
# [539 rows x 9 columns]

# %%
original_names = confirmed_cases.columns.to_list()
column_names = ['id','date','city','department','status','age','gender','origin','related_origin_country']
column_types = ['int','str','str','str','str','str','str','str','str']

df = ( confirmed_cases.copy()
      .astype(  dtype={k:v for k,v in zip(original_names, column_types)})
      .rename(columns={k:v for k,v in zip(original_names, column_names)})
     ).set_index('id')
df['date'] = pd.to_datetime(df['date'],dayfirst=True)
df.head()
# Out:
#          date      city department      status      age gender       origin  \
# id
# 1  2020-03-06    Bogotá     Bogotá  Recuperado  10 a 19      F    Importado
# 2  2020-03-09      Buga      Valle  Recuperado  30 a 39      M    Importado
# 3  2020-03-09  Medellín  Antioquia  Recuperado  50 a 59      F    Importado
# 4  2020-03-11  Medellín  Antioquia     En casa  50 a 59      M  Relacionado
# 5  2020-03-11  Medellín  Antioquia  Recuperado  20 a 29      M  Relacionado
#
#    related_origin_country
# id
# 1                  Italia
# 2                  España
# 3                  España
# 4                Colombia
# 5                Colombia

# %%
df_daily = ( df.groupby(['date'])
            .apply(len)
            .reset_index()
            .rename(columns={0:'new_confirmed_daily'})
           )
df_daily['aggregate'] = pd.Series([df_daily['new_confirmed_daily'].iloc[:i+1].sum() for i in df_daily.index])

# %%
df_daily
# Out:
#          date  new_confirmed_daily  aggregate
# 0  2020-03-06                    1          1
# 1  2020-03-09                    2          3
# 2  2020-03-11                    6          9
# 3  2020-03-12                    4         13
# 4  2020-03-13                    3         16
# 5  2020-03-14                    8         24
# 6  2020-03-15                   21         45
# 7  2020-03-16                   12         57
# 8  2020-03-17                   18         75
# 9  2020-03-18                   27        102
# 10 2020-03-19                   26        128
# 11 2020-03-20                   47        175
# 12 2020-03-21                   35        210
# 13 2020-03-22                   30        240
# 14 2020-03-23                   66        306
# 15 2020-03-24                  113        419
# 16 2020-03-25                   62        481
# 17 2020-03-26                   10        491
# 18 2020-03-27                   48        539

# %%
import seaborn as sns
sns.set(style="darkgrid")
sns.lineplot(data=df_daily[['date','aggregate']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-93d6ee52c226> in <module>
#       1 import seaborn as sns
#       2 sns.set(style="darkgrid")
# ----> 3 sns.lineplot(data=df_daily[['date','aggregate']])
#
# d:\python\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1129         dashes=dashes, markers=markers, style_order=style_order,
#    1130         units=units, estimator=estimator, ci=ci, n_boot=n_boot, seed=seed,
# -> 1131         sort=sort, err_style=err_style, err_kws=err_kws, legend=legend,
#    1132     )
#    1133
#
# d:\python\lib\site-packages\seaborn\relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend)
#     698
#     699         plot_data = self.establish_variables(
# --> 700             x, y, hue, size, style, units, data
#     701         )
#     702
#
# d:\python\lib\site-packages\seaborn\relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#      59                 # Enforce numeric values
#      60                 try:
# ---> 61                     data.astype(np.float)
#      62                 except ValueError:
#      63                     err = "A wide-form input must have only numeric values."
#
# d:\python\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# d:\python\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# d:\python\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# d:\python\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#    2213
#    2214         # delegate
# -> 2215         return super().astype(dtype=dtype, copy=copy, errors=errors)
#    2216
#    2217     def _can_hold_element(self, element: Any) -> bool:
#
# d:\python\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# d:\python\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     839             return arr.astype(dtype)
#     840
# --> 841         raise TypeError(f"cannot astype a datetimelike from [{arr.dtype}] to [{dtype}]")
#     842
#     843     elif is_timedelta64_dtype(arr):
#
# TypeError: cannot astype a datetimelike from [datetime64[ns]] to [float64]
